# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Cost-curve-investigation" data-toc-modified-id="Cost-curve-investigation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Cost curve investigation</a></span><ul class="toc-item"><li><span><a href="#Baseline-baseline" data-toc-modified-id="Baseline-baseline-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Baseline baseline</a></span></li><li><span><a href="#Cost-curve-evolution" data-toc-modified-id="Cost-curve-evolution-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Cost curve evolution</a></span></li><li><span><a href="#One-cost-curve-detail" data-toc-modified-id="One-cost-curve-detail-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>One cost curve detail</a></span></li><li><span><a href="#Evolution-of-average-costs" data-toc-modified-id="Evolution-of-average-costs-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Evolution of average costs</a></span></li></ul></li><li><span><a href="#Cobalt-behavior-under-different-shocks" data-toc-modified-id="Cobalt-behavior-under-different-shocks-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Cobalt behavior under different shocks</a></span><ul class="toc-item"><li><span><a href="#Baseline-and-scenarios" data-toc-modified-id="Baseline-and-scenarios-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Baseline and scenarios</a></span></li><li><span><a href="#Cobalt-mining-response" data-toc-modified-id="Cobalt-mining-response-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Cobalt mining response</a></span><ul class="toc-item"><li><span><a href="#Old-mines" data-toc-modified-id="Old-mines-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Old mines</a></span></li><li><span><a href="#New-mines" data-toc-modified-id="New-mines-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>New mines</a></span></li></ul></li><li><span><a href="#All-mine-responses" data-toc-modified-id="All-mine-responses-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>All mine responses</a></span></li><li><span><a href="#Cobalt-co-producing-mines-on-the-cost-curve" data-toc-modified-id="Cobalt-co-producing-mines-on-the-cost-curve-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Cobalt co-producing mines on the cost curve</a></span></li></ul></li><li><span><a href="#Tellurium-(refinery-behavior)-under-different-shocks" data-toc-modified-id="Tellurium-(refinery-behavior)-under-different-shocks-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Tellurium (refinery behavior) under different shocks</a></span><ul class="toc-item"><li><span><a href="#Baseline-and-scenarios" data-toc-modified-id="Baseline-and-scenarios-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Baseline and scenarios</a></span></li><li><span><a href="#Primary-mining-displacement" data-toc-modified-id="Primary-mining-displacement-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Primary mining displacement</a></span></li><li><span><a href="#Primary-refined-displacement" data-toc-modified-id="Primary-refined-displacement-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Primary refined displacement</a></span></li><li><span><a href="#Secondary-refined-displacement" data-toc-modified-id="Secondary-refined-displacement-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Secondary refined displacement</a></span></li><li><span><a href="#All-cathode-production-displacement" data-toc-modified-id="All-cathode-production-displacement-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>All cathode production displacement</a></span></li><li><span><a href="#Refined-usage-displacement" data-toc-modified-id="Refined-usage-displacement-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Refined usage displacement</a></span></li><li><span><a href="#Direct-melt-displacement" data-toc-modified-id="Direct-melt-displacement-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Direct melt displacement</a></span></li><li><span><a href="#All-demand-displacement" data-toc-modified-id="All-demand-displacement-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>All demand displacement</a></span></li><li><span><a href="#Supply-potentials" data-toc-modified-id="Supply-potentials-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Supply potentials</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from datetime import datetime
from dateutil.relativedelta import relativedelta
idx = pd.IndexSlice
import random 
from scipy import stats

from mine_simulation_tools import *
from cost_curve_tools import *

# %% [markdown]
# # Cost curve investigation

# %% [markdown]
# ## Baseline baseline

# %%
mine_life_baseline_baseline_tp=pd.read_excel('Data/scenario results/Mine level info/mine life baseline_baseline.xlsx', 
                                          sheet_name='Sheet1', index_col=[0, 1])
mine_life_baseline_baseline=mine_life_baseline_baseline_tp.transpose()

# %%
price_baseline_baseline=pd.read_excel('Data/scenario results/price baseline_baseline.xlsx', sheet_name='Sheet1', index_col=0)

# %% [markdown]
# ## Cost curve evolution

# %%
cc_18=cost_curve_df(2018, mine_life_baseline_baseline)
cc_25=cost_curve_df(2025, mine_life_baseline_baseline)
cc_30=cost_curve_df(2030, mine_life_baseline_baseline)
cc_35=cost_curve_df(2035, mine_life_baseline_baseline)
cc_40=cost_curve_df(2040, mine_life_baseline_baseline)

# %%
cc_18
# Out:
#             Total cost Cumulative production  \
# Mine ID
# 36399      1350.403605                    24
# 75974      1433.743333               135.403
# 75984      1522.025181               156.625
# 76101      1550.554353                186.19
# 26942      1605.707089               224.746
# 26942_dup  1605.707089               263.301
# 81508      1656.952753               273.301
# 80830      1674.562265               277.851
# 36012      1676.043153               278.306
# 29632      1718.077077               278.982
# 75976      1730.964316               331.634
# 33937      1891.038820                343.12
# 75978      1904.810596                345.12
# 29461      1907.145575               419.294
# 75983      1944.764659               502.382
# 26568      1971.992290               1087.21
# 28022      1976.817167               1090.96
# 27868      2030.811683               1136.54
# 25790      2095.347723               1141.57
# 30531      2106.157526               1151.57
# ...

# %%
# %matplotlib notebook
plt.style.use('ggplot')
plt.step(cc_18.loc[:, 'Cumulative production'].shift(1).fillna(0), cc_18.loc[:, 'Total cost'], where='post')
plt.step(cc_25.loc[:, 'Cumulative production'].shift(1).fillna(0), cc_25.loc[:, 'Total cost'], where='post')
plt.step(cc_30.loc[:, 'Cumulative production'].shift(1).fillna(0), cc_30.loc[:, 'Total cost'], where='post')
plt.step(cc_35.loc[:, 'Cumulative production'].shift(1).fillna(0), cc_35.loc[:, 'Total cost'], where='post')
plt.step(cc_40.loc[:, 'Cumulative production'].shift(1).fillna(0), cc_40.loc[:, 'Total cost'], where='post')

plt.xlabel('Cumulative copper production (ktonnes)')
plt.ylabel('Total cash costs (dollars per tonne of paid metal)')

plt.title('Cost curve evolution')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## One cost curve detail

# %%
x_pos=cc_18.loc[:, 'Cumulative production'].shift(1).fillna(0)
width=cc_18.loc[:, 'Cumulative production'].diff().fillna(cc_18.loc[:, 'Cumulative production'].iloc[0])
minesite=cc_18.loc[:, 'Minsite cost ($/tonne paid metal)']
freight=cc_18.loc[:, 'Frieght ($/tonne paid metal)']
tcrc=cc_18.loc[:, 'TCRC ($/tonne paid metal)']
royalty=cc_18.loc[:, 'Royalty ($/tonne paid metal)']
cathode_price=price_baseline_baseline.loc['20180101', 'Cathode']

# %%
# %matplotlib notebook
plt.bar(x_pos, minesite, color='b', align='edge', edgecolor='black', width=width, linewidth=0.15,
        label='Minesite')
plt.bar(x_pos, freight, color='r', align='edge', edgecolor='black', width=width, bottom=minesite, linewidth=0.15,
        label='Freight')
plt.bar(x_pos, tcrc, color='g', align='edge', edgecolor='black', width=width, bottom=minesite+freight, linewidth=0.15,
        label='TCRC')
plt.bar(x_pos, royalty, color='purple', align='edge', edgecolor='black', width=width, bottom=minesite+freight+tcrc, linewidth=0.15,
        label='Royalty')

plt.plot([0, x_pos.iloc[-1]], [cathode_price, cathode_price], color='orange')
plt.title('2040 Cost curve (Total cash costs, co-product basis)')
plt.xlabel('Cumulative copper production (ktonnes)')
plt.ylabel('Total cash costs (dollars per tonne of paid metal)')
plt.axis([-1000, x_pos.iloc[-1]+1000, 0, 8000])
#plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Evolution of average costs

# %%
cost_series_median=cost_percentile_series(mine_life_baseline_baseline, percentile=50)
cost_series_25=cost_percentile_series(mine_life_baseline_baseline, percentile=25)
cost_series_75=cost_percentile_series(mine_life_baseline_baseline, percentile=75)

# %%
# %matplotlib notebook
plt.style.use('ggplot')
plt.plot(pd.Series(price_baseline_baseline.loc['20180101':, 'Cathode'].values, index=np.arange(2018, 2041)), label='Cathode price')
plt.plot(cost_series_median, label='Median cost')
plt.plot(cost_series_25, label='Lower quartile cost')
plt.plot(cost_series_75, label='Upper quartile cost')

plt.title('Cathode price and total cash costs (dollars per tonne)')
# plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
minesite_average=mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']]\
.mul(mine_life_baseline_baseline.loc[:, idx[:, 'Minsite cost ($/tonne paid metal)']].values).sum(axis=1)\
.div(mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].sum(axis=1))

# %%
tcrc_average=mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']]\
.mul(mine_life_baseline_baseline.loc[:, idx[:, 'TCRC ($/tonne paid metal)']].values).sum(axis=1)\
.div(mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].sum(axis=1))

# %%
freight_average=mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']]\
.mul(mine_life_baseline_baseline.loc[:, idx[:, 'Frieght ($/tonne paid metal)']].values).sum(axis=1)\
.div(mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].sum(axis=1))

# %%
royalty_average=mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']]\
.mul(mine_life_baseline_baseline.loc[:, idx[:, 'Royalty ($/tonne paid metal)']].values).sum(axis=1)\
.div(mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].sum(axis=1))

# %%
# %matplotlib notebook
plt.plot(minesite_average, 'b', label='Minesite cost simulated')
plt.plot(freight_average, 'r', label='Freight cost simulated')
plt.plot(tcrc_average, 'g', label='TCRC simulated')
plt.plot(royalty_average, 'purple', label='Royalty simulated')

plt.title('Evolution of total cash costs (dollars per tonne)')
#plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Cobalt behavior under different shocks

# %%
def dislpacement_estimate(sd_scenario, scrap_baseline, mining_baseline):
    scrap_supply_scenario=sd_scenario.loc['19600101':, 'Scrap production']
    mining_supply_scenario=sd_scenario.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
    shock_scenario=scrap_supply_scenario-scrap_baseline
    mining_response_scenario=mining_supply_scenario-mining_baseline
    displacement_scenario=mining_response_scenario.cumsum().div(shock_scenario.cumsum()).mul(-1)
    
    dis_results=pd.DataFrame({'Shock': shock_scenario, 'Mining response': mining_response_scenario, 
                              'Displacement': displacement_scenario})
    return dis_results

# %%
sd_baseline_baseline=pd.read_excel('Data/scenario results/S&D baseline_baseline.xlsx', 
                                   sheet_name='Sheet1', index_col=0)
scrap_supply_baseline_baseline=sd_baseline_baseline.loc['19600101':, 'Scrap production']
mining_supply_baseline_baseline=sd_baseline_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %%
sd_baseline_sm=pd.read_excel('Data/scenario results/S&D baseline_sm.xlsx', sheet_name='Sheet1', index_col=0)
shock_baseline_sm=dislpacement_estimate(
    sd_baseline_sm, scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']

# %%
sd_baseline_rs10=pd.read_excel('Data/scenario results/S&D baseline_rs10.xlsx', sheet_name='Sheet1', index_col=0)
shock_baseline_rs10=dislpacement_estimate(
    sd_baseline_rs10, scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']

# %%
sd_baseline_rs20=pd.read_excel('Data/scenario results/S&D baseline_rs20.xlsx', sheet_name='Sheet1', index_col=0)
shock_baseline_rs20=dislpacement_estimate(
    sd_baseline_rs20, scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']

# %%
sd_baseline_rs50=pd.read_excel('Data/scenario results/S&D baseline_rs50.xlsx', sheet_name='Sheet1', index_col=0)
shock_baseline_rs50=dislpacement_estimate(
    sd_baseline_rs50, scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']

# %%
sd_baseline_rs100=pd.read_excel('Data/scenario results/S&D baseline_rs100.xlsx', sheet_name='Sheet1', index_col=0)
shock_baseline_rs100=dislpacement_estimate(
    sd_baseline_rs100, scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']

# %%
sd_baseline_prs10=pd.read_excel('Data/scenario results/S&D baseline_prs10.xlsx', sheet_name='Sheet1', index_col=0)
shock_baseline_prs10=dislpacement_estimate(
    sd_baseline_prs10, scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']

# %%
sd_baseline_prs20=pd.read_excel('Data/scenario results/S&D baseline_prs20.xlsx', sheet_name='Sheet1', index_col=0)
shock_baseline_prs20=dislpacement_estimate(
    sd_baseline_prs20, scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']

# %%
sd_baseline_prs50=pd.read_excel('Data/scenario results/S&D baseline_prs50.xlsx', sheet_name='Sheet1', index_col=0)
shock_baseline_prs50=dislpacement_estimate(
    sd_baseline_prs50, scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']

# %%
sd_baseline_prs100=pd.read_excel('Data/scenario results/S&D baseline_prs100.xlsx', sheet_name='Sheet1', index_col=0)
shock_baseline_prs100=dislpacement_estimate(
    sd_baseline_prs100, scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']

# %% [markdown]
# ## Baseline and scenarios

# %%
mine_life_baseline_baseline_tp=pd.read_excel('Data/scenario results/Mine level info/mine life baseline_baseline.xlsx', 
                                          sheet_name='Sheet1', index_col=[0, 1])
mine_life_baseline_baseline=mine_life_baseline_baseline_tp.transpose()

# %%
mine_life_baseline_sm_tp=pd.read_excel('Data/scenario results/Mine level info/mine life baseline_sm.xlsx', 
                                          sheet_name='Sheet1', index_col=[0, 1])
mine_life_baseline_sm=mine_life_baseline_sm_tp.transpose()

# %%
mine_life_baseline_rs10_tp=pd.read_excel('Data/scenario results/Mine level info/mine life baseline_rs10.xlsx', 
                                          sheet_name='Sheet1', index_col=[0, 1])
mine_life_baseline_rs10=mine_life_baseline_rs10_tp.transpose()

# %%
mine_life_baseline_rs20_tp=pd.read_excel('Data/scenario results/Mine level info/mine life baseline_rs20.xlsx', 
                                          sheet_name='Sheet1', index_col=[0, 1])
mine_life_baseline_rs20=mine_life_baseline_rs20_tp.transpose()

# %%
mine_life_baseline_rs50_tp=pd.read_excel('Data/scenario results/Mine level info/mine life baseline_rs50.xlsx', 
                                          sheet_name='Sheet1', index_col=[0, 1])
mine_life_baseline_rs50=mine_life_baseline_rs50_tp.transpose()

# %%
mine_life_baseline_rs100_tp=pd.read_excel('Data/scenario results/Mine level info/mine life baseline_rs100.xlsx', 
                                          sheet_name='Sheet1', index_col=[0, 1])
mine_life_baseline_rs100=mine_life_baseline_rs100_tp.transpose()

# %%
mine_life_baseline_prs10_tp=pd.read_excel('Data/scenario results/Mine level info/mine life baseline_prs10.xlsx', 
                                          sheet_name='Sheet1', index_col=[0, 1])
mine_life_baseline_prs10=mine_life_baseline_prs10_tp.transpose()

# %%
mine_life_baseline_prs20_tp=pd.read_excel('Data/scenario results/Mine level info/mine life baseline_prs20.xlsx', 
                                          sheet_name='Sheet1', index_col=[0, 1])
mine_life_baseline_prs20=mine_life_baseline_prs20_tp.transpose()

# %%
mine_life_baseline_prs50_tp=pd.read_excel('Data/scenario results/Mine level info/mine life baseline_prs50.xlsx', 
                                          sheet_name='Sheet1', index_col=[0, 1])
mine_life_baseline_prs50=mine_life_baseline_prs50_tp.transpose()

# %%
mine_life_baseline_prs100_tp=pd.read_excel('Data/scenario results/Mine level info/mine life baseline_prs100.xlsx', 
                                          sheet_name='Sheet1', index_col=[0, 1])
mine_life_baseline_prs100=mine_life_baseline_prs100_tp.transpose()

# %% [markdown]
# ## Cobalt mining response

# %% [markdown]
# ### Old mines

# %%
cu_co_mines=pd.read_excel('Cobalt/Mines affected.xlsx', sheet_name='Old mines', index_col=0)
cu_co_id=cu_co_mines.index
co_cu_ratio=cu_co_mines.loc[:, '2018 Co prod (kt)'].div(cu_co_mines.loc[:, '2018 Cu prod (kt)'])

# %% [markdown]
# Assuming that Co production will respond to the same Co-to-Cu ratio as in 2018

# %%
mine_life_response_baseline_sm_old=mine_life_baseline_sm.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)-\
mine_life_baseline_baseline.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)

mine_life_response_baseline_sm_old.columns=mine_life_response_baseline_sm_old.columns.get_level_values(0)
co_response_baseline_sm_old=mine_life_response_baseline_sm_old.mul(co_cu_ratio).sum(axis=1)

# %%
mine_life_response_baseline_rs10_old=mine_life_baseline_rs10.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)-\
mine_life_baseline_baseline.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)

mine_life_response_baseline_rs10_old.columns=mine_life_response_baseline_rs10_old.columns.get_level_values(0)
co_response_baseline_rs10_old=mine_life_response_baseline_rs10_old.mul(co_cu_ratio).sum(axis=1)

# %%
mine_life_response_baseline_rs20_old=mine_life_baseline_rs20.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)-\
mine_life_baseline_baseline.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)

mine_life_response_baseline_rs20_old.columns=mine_life_response_baseline_rs20_old.columns.get_level_values(0)
co_response_baseline_rs20_old=mine_life_response_baseline_rs20_old.mul(co_cu_ratio).sum(axis=1)

# %%
mine_life_response_baseline_rs50_old=mine_life_baseline_rs50.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)-\
mine_life_baseline_baseline.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)

mine_life_response_baseline_rs50_old.columns=mine_life_response_baseline_rs50_old.columns.get_level_values(0)
co_response_baseline_rs50_old=mine_life_response_baseline_rs50_old.mul(co_cu_ratio).sum(axis=1)

# %%
mine_life_response_baseline_rs100_old=mine_life_baseline_rs100.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)-\
mine_life_baseline_baseline.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)

mine_life_response_baseline_rs100_old.columns=mine_life_response_baseline_rs100_old.columns.get_level_values(0)
co_response_baseline_rs100_old=mine_life_response_baseline_rs100_old.mul(co_cu_ratio).sum(axis=1)

# %%
mine_life_response_baseline_prs10_old=mine_life_baseline_prs10.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)-\
mine_life_baseline_baseline.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)

mine_life_response_baseline_prs10_old.columns=mine_life_response_baseline_prs10_old.columns.get_level_values(0)
co_response_baseline_prs10_old=mine_life_response_baseline_prs10_old.mul(co_cu_ratio).sum(axis=1)

# %%
mine_life_response_baseline_prs20_old=mine_life_baseline_prs20.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)-\
mine_life_baseline_baseline.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)

mine_life_response_baseline_prs20_old.columns=mine_life_response_baseline_prs20_old.columns.get_level_values(0)
co_response_baseline_prs20_old=mine_life_response_baseline_prs20_old.mul(co_cu_ratio).sum(axis=1)

# %%
mine_life_response_baseline_prs50_old=mine_life_baseline_prs50.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)-\
mine_life_baseline_baseline.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)

mine_life_response_baseline_prs50_old.columns=mine_life_response_baseline_prs50_old.columns.get_level_values(0)
co_response_baseline_prs50_old=mine_life_response_baseline_prs50_old.mul(co_cu_ratio).sum(axis=1)

# %%
mine_life_response_baseline_prs100_old=mine_life_baseline_prs100.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)-\
mine_life_baseline_baseline.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].fillna(0)

mine_life_response_baseline_prs100_old.columns=mine_life_response_baseline_prs100_old.columns.get_level_values(0)
co_response_baseline_prs100_old=mine_life_response_baseline_prs100_old.mul(co_cu_ratio).sum(axis=1)

# %% [markdown]
# Marginal response

# %%
displacement_co_baseline_sm_old=-co_response_baseline_sm_old.cumsum().div(shock_baseline_sm.cumsum())

displacement_co_baseline_rs10_old=-co_response_baseline_rs10_old.cumsum().div(shock_baseline_rs10.cumsum())
displacement_co_baseline_rs20_old=-co_response_baseline_rs20_old.cumsum().div(shock_baseline_rs20.cumsum())
displacement_co_baseline_rs50_old=-co_response_baseline_rs50_old.cumsum().div(shock_baseline_rs50.cumsum())
displacement_co_baseline_rs100_old=-co_response_baseline_rs100_old.cumsum().div(shock_baseline_rs100.cumsum())

displacement_co_baseline_prs10_old=-co_response_baseline_prs10_old.cumsum().div(shock_baseline_prs10.cumsum())
displacement_co_baseline_prs20_old=-co_response_baseline_prs20_old.cumsum().div(shock_baseline_prs20.cumsum())
displacement_co_baseline_prs50_old=-co_response_baseline_prs50_old.cumsum().div(shock_baseline_prs50.cumsum())
displacement_co_baseline_prs100_old=-co_response_baseline_prs100_old.cumsum().div(shock_baseline_prs100.cumsum())

# %%
# %matplotlib notebook
plt.plot(displacement_co_baseline_sm_old, label='Marginal')
plt.plot(displacement_co_baseline_rs100_old, label='100%')
plt.plot(displacement_co_baseline_prs10_old, label='P10%')
plt.plot(displacement_co_baseline_prs20_old, label='P20%')
plt.plot(displacement_co_baseline_prs50_old, label='P50%')
plt.plot(displacement_co_baseline_prs100_old, label='P100%')

plt.title('Displacement of cobalt, old mines')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### New mines

# %% [markdown]
# Assuming some co_cu_ratio for all new mines (starting with 'Inc'), which is not constant... But doing so allows us to calibrate to future cobalt mining benchmark

# %%
old_cu_prod=mine_life_baseline_baseline.loc[:, idx[cu_co_id, 'Recovered metal production (kt)']].copy()
old_cu_prod.columns=old_cu_prod.columns.get_level_values(0)

old_co_prod_total=old_cu_prod.mul(co_cu_ratio).sum(axis=1)

# %%
future_co_prod_total=pd.read_excel('Cobalt/Mines affected.xlsx', sheet_name='New mines', index_col=0)
new_co_prod_total_cali=(future_co_prod_total.iloc[:, 0].div(1e3)-old_co_prod_total)
new_cu_prod=mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)

new_co_cu_ratio=new_co_prod_total_cali.div(new_cu_prod)

# %%
mine_life_response_baseline_sm_new=mine_life_baseline_sm.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)-\
mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)

co_response_baseline_sm_new=mine_life_response_baseline_sm_new.mul(new_co_cu_ratio, axis=0)

# %%
mine_life_response_baseline_rs10_new=mine_life_baseline_rs10.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)-\
mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)

co_response_baseline_rs10_new=mine_life_response_baseline_rs10_new.mul(new_co_cu_ratio, axis=0)

# %%
mine_life_response_baseline_rs20_new=mine_life_baseline_rs20.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)-\
mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)

co_response_baseline_rs20_new=mine_life_response_baseline_rs20_new.mul(new_co_cu_ratio, axis=0)

# %%
mine_life_response_baseline_rs50_new=mine_life_baseline_rs50.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)-\
mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)

co_response_baseline_rs50_new=mine_life_response_baseline_rs50_new.mul(new_co_cu_ratio, axis=0)

# %%
mine_life_response_baseline_rs100_new=mine_life_baseline_rs100.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)-\
mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)

co_response_baseline_rs100_new=mine_life_response_baseline_rs100_new.mul(new_co_cu_ratio, axis=0)

# %%
mine_life_response_baseline_prs10_new=mine_life_baseline_prs10.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)-\
mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)

co_response_baseline_prs10_new=mine_life_response_baseline_prs10_new.mul(new_co_cu_ratio, axis=0)

# %%
mine_life_response_baseline_prs20_new=mine_life_baseline_prs20.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)-\
mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)

co_response_baseline_prs20_new=mine_life_response_baseline_prs20_new.mul(new_co_cu_ratio, axis=0)

# %%
mine_life_response_baseline_prs50_new=mine_life_baseline_prs50.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)-\
mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)

co_response_baseline_prs50_new=mine_life_response_baseline_prs50_new.mul(new_co_cu_ratio, axis=0)

# %%
mine_life_response_baseline_prs100_new=mine_life_baseline_prs100.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)-\
mine_life_baseline_baseline.loc[:, idx[:, 'Recovered metal production (kt)']].iloc[:, 430:].sum(axis=1)

co_response_baseline_prs100_new=mine_life_response_baseline_prs100_new.mul(new_co_cu_ratio, axis=0)

# %% [markdown]
# ## All mine responses

# %%
co_response_baseline_rs10_all=co_response_baseline_rs10_new.cumsum()+co_response_baseline_rs10_old.cumsum()
co_response_baseline_rs20_all=co_response_baseline_rs20_new.cumsum()+co_response_baseline_rs20_old.cumsum()
co_response_baseline_rs50_all=co_response_baseline_rs50_new.cumsum()+co_response_baseline_rs50_old.cumsum()
co_response_baseline_rs100_all=co_response_baseline_rs100_new.cumsum()+co_response_baseline_rs100_old.cumsum()

# %%
co_response_baseline_prs10_all=co_response_baseline_prs10_new.cumsum()+co_response_baseline_prs10_old.cumsum()
co_response_baseline_prs20_all=co_response_baseline_prs20_new.cumsum()+co_response_baseline_prs20_old.cumsum()
co_response_baseline_prs50_all=co_response_baseline_prs50_new.cumsum()+co_response_baseline_prs50_old.cumsum()
co_response_baseline_prs100_all=co_response_baseline_prs100_new.cumsum()+co_response_baseline_prs100_old.cumsum()

# %%
displacement_co_baseline_sm_new=-co_response_baseline_sm_new.cumsum().div(shock_baseline_sm.cumsum())
displacement_co_baseline_rs100_new=-co_response_baseline_rs100_new.cumsum().div(shock_baseline_rs100.cumsum())
displacement_co_baseline_prs10_new=-co_response_baseline_prs10_new.cumsum().div(shock_baseline_prs10.cumsum())
displacement_co_baseline_prs20_new=-co_response_baseline_prs20_new.cumsum().div(shock_baseline_prs20.cumsum())
displacement_co_baseline_prs50_new=-co_response_baseline_prs50_new.cumsum().div(shock_baseline_prs50.cumsum())
displacement_co_baseline_prs100_new=-co_response_baseline_prs100_new.cumsum().div(shock_baseline_prs100.cumsum())

# %%
displacement_co_baseline_sm_all=displacement_co_baseline_sm_old+displacement_co_baseline_sm_new
displacement_co_baseline_rs100_all=displacement_co_baseline_rs100_old+displacement_co_baseline_rs100_new
displacement_co_baseline_prs10_all=displacement_co_baseline_prs10_old+displacement_co_baseline_prs10_new
displacement_co_baseline_prs20_all=displacement_co_baseline_prs20_old+displacement_co_baseline_prs20_new
displacement_co_baseline_prs50_all=displacement_co_baseline_prs50_old+displacement_co_baseline_prs50_new
displacement_co_baseline_prs100_all=displacement_co_baseline_prs100_old+displacement_co_baseline_prs100_new

# %%
# %matplotlib notebook
plt.plot(displacement_co_baseline_sm_all, label='SM')
plt.plot(displacement_co_baseline_rs100_all, label='100%')
plt.plot(displacement_co_baseline_prs10_all, label='PRS10%')
plt.plot(displacement_co_baseline_prs20_all, label='PRS20%')
plt.plot(displacement_co_baseline_prs50_all, label='PRS50%')
plt.plot(displacement_co_baseline_prs100_all, label='PRS100%')

plt.title('Displacement of cobalt, all mines')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.plot(-co_response_baseline_rs10_all, label='10%')
plt.plot(-co_response_baseline_rs20_all, label='20%')
plt.plot(-co_response_baseline_rs50_all, label='50%')
plt.plot(-co_response_baseline_rs100_all, label='Maximum')
plt.plot([datetime(2018,1,1), datetime(2040,1,1)], [0, 0], 'k--')

plt.ylabel('Co mining production reduction (kt)')
plt.xlabel('Year')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Cobalt co-producing mines on the cost curve

# %%
x_pos_co=cc_18.loc[:, 'Cumulative production'].shift(1).fillna(0).loc[cu_co_id]
width_co=cc_18.loc[:, 'Cumulative production'].diff().fillna(cc_18.loc[:, 'Cumulative production'].iloc[0]).loc[cu_co_id]
minesite_co=cc_18.loc[:, 'Minsite cost ($/tonne paid metal)'].loc[cu_co_id]
freight_co=cc_18.loc[:, 'Frieght ($/tonne paid metal)'].loc[cu_co_id]
tcrc_co=cc_18.loc[:, 'TCRC ($/tonne paid metal)'].loc[cu_co_id]
royalty_co=cc_18.loc[:, 'Royalty ($/tonne paid metal)'].loc[cu_co_id]
cathode_price=price_baseline_baseline.loc['20180101', 'Cathode']

# %%
# %matplotlib notebook
plt.step(cc_18.loc[:, 'Cumulative production'].shift(1).fillna(0), cc_18.loc[:, 'Total cost'], where='post')
plt.bar(x_pos_co, minesite_co, color='b', align='edge', edgecolor='black', width=width_co, 
        linewidth=0.5, label='Minesite')
plt.bar(x_pos_co, freight_co, color='r', align='edge', edgecolor='black', width=width_co, 
        bottom=minesite_co, linewidth=0.5, label='Freight')
plt.bar(x_pos_co, tcrc_co, color='g', align='edge', edgecolor='black', width=width_co, 
        bottom=minesite_co+freight_co, linewidth=0.5, label='TCRC')
plt.bar(x_pos_co, royalty_co, color='purple', align='edge', edgecolor='black', width=width_co, 
        bottom=minesite_co+freight_co+tcrc_co, linewidth=0.5, label='Royalty')

plt.plot([0, x_pos.iloc[-1]], [cathode_price, cathode_price], color='orange')
# plt.title('2018 Cost curve (Total cash costs, co-product basis)')
plt.xlabel('Cumulative copper production (ktonnes)')
plt.ylabel('Total cash costs (dollars per tonne of paid metal)')
plt.axis([-1000, x_pos.iloc[-1]+1000, 0, 8000])
#plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Tellurium (refinery behavior) under different shocks

# %% [markdown]
# Question to ask: how much primary refinery production is avoided due to scrap supply shocks?

# %% [markdown]
# ## Baseline and scenarios

# %%
sd_baseline_baseline=pd.read_excel('Data/scenario results/S&D baseline_baseline.xlsx', 
                                   sheet_name='Sheet1', index_col=0)

# %%
sd_baseline_sm=pd.read_excel('Data/scenario results/S&D baseline_sm.xlsx', 
                             sheet_name='Sheet1', index_col=0)
sd_baseline_prs10=pd.read_excel('Data/scenario results/S&D baseline_prs10.xlsx', sheet_name='Sheet1', index_col=0)
sd_baseline_prs20=pd.read_excel('Data/scenario results/S&D baseline_prs20.xlsx', sheet_name='Sheet1', index_col=0)
sd_baseline_prs50=pd.read_excel('Data/scenario results/S&D baseline_prs50.xlsx', sheet_name='Sheet1', index_col=0)
sd_baseline_prs100=pd.read_excel('Data/scenario results/With sp2 constraint/S&D baseline_prs100.xlsx', sheet_name='Sheet1', index_col=0)

# %%
shock_baseline_sm=dislpacement_estimate(sd_baseline_sm, 
                                        scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']
shock_baseline_prs10=dislpacement_estimate(sd_baseline_prs10, 
                                        scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']
shock_baseline_prs20=dislpacement_estimate(sd_baseline_prs20, 
                                        scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']
shock_baseline_prs50=dislpacement_estimate(sd_baseline_prs50, 
                                        scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']
shock_baseline_prs100=dislpacement_estimate(sd_baseline_prs100, 
                                        scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2f3568a9da2d> in <module>()
#       1 shock_baseline_sm=dislpacement_estimate(sd_baseline_sm,
# ----> 2                                         scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']
#       3 shock_baseline_prs10=dislpacement_estimate(sd_baseline_prs10,
#       4                                         scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Shock']
#       5 shock_baseline_prs20=dislpacement_estimate(sd_baseline_prs20,
#
# NameError: name 'scrap_supply_baseline_baseline' is not defined

# %% [markdown]
# ## Primary mining displacement

# %%
mine_dis_baseline_sm=dislpacement_estimate(sd_baseline_sm, 
                                        scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Displacement']
mine_dis_baseline_prs10=dislpacement_estimate(sd_baseline_prs10, 
                                        scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Displacement']
mine_dis_baseline_prs20=dislpacement_estimate(sd_baseline_prs20, 
                                        scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Displacement']
mine_dis_baseline_prs50=dislpacement_estimate(sd_baseline_prs50, 
                                        scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Displacement']
mine_dis_baseline_prs100=dislpacement_estimate(sd_baseline_prs100, 
                                        scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Displacement']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-89acea146a2a> in <module>()
#       1 mine_dis_baseline_sm=dislpacement_estimate(sd_baseline_sm,
# ----> 2                                         scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Displacement']
#       3 mine_dis_baseline_prs10=dislpacement_estimate(sd_baseline_prs10,
#       4                                         scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:, 'Displacement']
#       5 mine_dis_baseline_prs20=dislpacement_estimate(sd_baseline_prs20,
#
# NameError: name 'scrap_supply_baseline_baseline' is not defined

# %%
# %matplotlib notebook
plt.plot(mine_dis_baseline_sm.loc['20180101':], label='Marginal')
plt.plot(mine_dis_baseline_prs10.loc['20180101':], label='prs10%')
plt.plot(mine_dis_baseline_prs20.loc['20180101':], label='prs20%')
plt.plot(mine_dis_baseline_prs50.loc['20180101':], label='prs50%')
plt.plot(mine_dis_baseline_prs100.loc['20180101':], label='prs100%')

plt.legend()
plt.title('Displacement of primary mining production')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Primary refined displacement

# %%
pri_ref_response_baseline_sm=sd_baseline_sm.loc['19600101':, 'Primary refining production']-\
sd_baseline_baseline.loc['19600101':, 'Primary refining production']

pri_ref_response_baseline_prs10=sd_baseline_prs10.loc['19600101':, 'Primary refining production']-\
sd_baseline_baseline.loc['19600101':, 'Primary refining production']

pri_ref_response_baseline_prs20=sd_baseline_prs20.loc['19600101':, 'Primary refining production']-\
sd_baseline_baseline.loc['19600101':, 'Primary refining production']

pri_ref_response_baseline_prs50=sd_baseline_prs50.loc['19600101':, 'Primary refining production']-\
sd_baseline_baseline.loc['19600101':, 'Primary refining production']

pri_ref_response_baseline_prs100=sd_baseline_prs100.loc['19600101':, 'Primary refining production']-\
sd_baseline_baseline.loc['19600101':, 'Primary refining production']

# %%
displacement_pri_ref_baseline_sm=-pri_ref_response_baseline_sm.loc['20190101':].cumsum()\
.div(shock_baseline_sm.loc['20190101':].cumsum())

displacement_pri_ref_baseline_prs10=-pri_ref_response_baseline_prs10.loc['20190101':].cumsum()\
.div(shock_baseline_prs10.loc['20190101':].cumsum())

displacement_pri_ref_baseline_prs20=-pri_ref_response_baseline_prs20.loc['20190101':].cumsum()\
.div(shock_baseline_prs20.loc['20190101':].cumsum())

displacement_pri_ref_baseline_prs50=-pri_ref_response_baseline_prs50.loc['20190101':].cumsum()\
.div(shock_baseline_prs50.loc['20190101':].cumsum())

displacement_pri_ref_baseline_prs100=-pri_ref_response_baseline_prs100.loc['20190101':].cumsum()\
.div(shock_baseline_prs100.loc['20190101':].cumsum())

# %%
# %matplotlib notebook
plt.plot(displacement_pri_ref_baseline_sm.loc['20180101':], label='Marginal')
plt.plot(displacement_pri_ref_baseline_prs10.loc['20180101':], label='prs10%')
plt.plot(displacement_pri_ref_baseline_prs20.loc['20180101':], label='prs20%')
plt.plot(displacement_pri_ref_baseline_prs50.loc['20180101':], label='prs50%')
plt.plot(displacement_pri_ref_baseline_prs100.loc['20180101':], label='prs100%')

#plt.legend()
plt.title('Displacement of primary refined production')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="NaN">

# %%
displacement_pri_ref_baseline_prs100
# Out:
# 2019-01-01   -0.000000
# 2020-01-01    0.061543
# 2021-01-01    0.075908
# 2022-01-01    0.066644
# 2023-01-01    0.058845
# 2024-01-01    0.052859
# 2025-01-01    0.048986
# 2026-01-01    0.049420
# 2027-01-01    0.061874
# 2028-01-01    0.082207
# 2029-01-01    0.101025
# 2030-01-01    0.113753
# 2031-01-01    0.119186
# 2032-01-01    0.121948
# 2033-01-01    0.123814
# 2034-01-01    0.120979
# 2035-01-01    0.112069
# 2036-01-01    0.103045
# 2037-01-01    0.097760
# 2038-01-01    0.097146
# 2039-01-01    0.100030
# 2040-01-01    0.107158
# dtype: float64

# %%
# %matplotlib notebook
plt.plot(-pri_ref_response_baseline_prs10.loc['20180101':].cumsum(), label='10%')
plt.plot(-pri_ref_response_baseline_prs20.loc['20180101':].cumsum(), label='20%')
plt.plot(-pri_ref_response_baseline_prs50.loc['20180101':].cumsum(), label='50%')
plt.plot(-pri_ref_response_baseline_prs100.loc['20180101':].cumsum(), label='Maximum')

plt.legend()
plt.ylabel('Reduction of primary refined production (kt)')
plt.xlabel('Year')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Secondary refined displacement

# %%
sec_ref_response_baseline_sm=sd_baseline_sm.loc['19600101':, 'Secondary refining production']-\
sd_baseline_baseline.loc['19600101':, 'Secondary refining production']

sec_ref_response_baseline_prs10=sd_baseline_prs10.loc['19600101':, 'Secondary refining production']-\
sd_baseline_baseline.loc['19600101':, 'Secondary refining production']

sec_ref_response_baseline_prs20=sd_baseline_prs20.loc['19600101':, 'Secondary refining production']-\
sd_baseline_baseline.loc['19600101':, 'Secondary refining production']

sec_ref_response_baseline_prs50=sd_baseline_prs50.loc['19600101':, 'Secondary refining production']-\
sd_baseline_baseline.loc['19600101':, 'Secondary refining production']

sec_ref_response_baseline_prs100=sd_baseline_prs100.loc['19600101':, 'Secondary refining production']-\
sd_baseline_baseline.loc['19600101':, 'Secondary refining production']

# %%
displacement_sec_ref_baseline_sm=-sec_ref_response_baseline_sm.loc['20190101':].cumsum()\
.div(shock_baseline_sm.loc['20190101':].cumsum())

displacement_sec_ref_baseline_prs10=-sec_ref_response_baseline_prs10.loc['20190101':].cumsum()\
.div(shock_baseline_prs10.loc['20190101':].cumsum())

displacement_sec_ref_baseline_prs20=-sec_ref_response_baseline_prs20.loc['20190101':].cumsum()\
.div(shock_baseline_prs20.loc['20190101':].cumsum())

displacement_sec_ref_baseline_prs50=-sec_ref_response_baseline_prs50.loc['20190101':].cumsum()\
.div(shock_baseline_prs50.loc['20190101':].cumsum())

displacement_sec_ref_baseline_prs100=-sec_ref_response_baseline_prs100.loc['20190101':].cumsum()\
.div(shock_baseline_prs100.loc['20190101':].cumsum())

# %%
# %matplotlib notebook
plt.plot(displacement_sec_ref_baseline_sm.loc['20180101':], label='Marginal')
plt.plot(displacement_sec_ref_baseline_prs10.loc['20180101':], label='prs10%')
plt.plot(displacement_sec_ref_baseline_prs20.loc['20180101':], label='prs20%')
plt.plot(displacement_sec_ref_baseline_prs50.loc['20180101':], label='prs50%')
plt.plot(displacement_sec_ref_baseline_prs100.loc['20180101':], label='prs100%')

#plt.legend()
plt.title('Response ratio of secondary refined production')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## All cathode production displacement

# %%
all_ref_response_baseline_sm=sd_baseline_sm.iloc[10:, 3:5].sum(axis=1)-sd_baseline_baseline.iloc[10:, 3:5].sum(axis=1)
all_ref_response_baseline_prs10=sd_baseline_prs10.iloc[10:, 3:5].sum(axis=1)-sd_baseline_baseline.iloc[10:, 3:5].sum(axis=1)
all_ref_response_baseline_prs20=sd_baseline_prs20.iloc[10:, 3:5].sum(axis=1)-sd_baseline_baseline.iloc[10:, 3:5].sum(axis=1)
all_ref_response_baseline_prs50=sd_baseline_prs50.iloc[10:, 3:5].sum(axis=1)-sd_baseline_baseline.iloc[10:, 3:5].sum(axis=1)
all_ref_response_baseline_prs100=sd_baseline_prs100.iloc[10:, 3:5].sum(axis=1)-sd_baseline_baseline.iloc[10:, 3:5].sum(axis=1)

# %%
displacement_all_ref_baseline_sm=-all_ref_response_baseline_sm.loc['20190101':].cumsum()\
.div(shock_baseline_sm.loc['20190101':].cumsum())

displacement_all_ref_baseline_prs10=-all_ref_response_baseline_prs10.loc['20190101':].cumsum()\
.div(shock_baseline_prs10.loc['20190101':].cumsum())

displacement_all_ref_baseline_prs20=-all_ref_response_baseline_prs20.loc['20190101':].cumsum()\
.div(shock_baseline_prs20.loc['20190101':].cumsum())

displacement_all_ref_baseline_prs50=-all_ref_response_baseline_prs50.loc['20190101':].cumsum()\
.div(shock_baseline_prs50.loc['20190101':].cumsum())

displacement_all_ref_baseline_prs100=-all_ref_response_baseline_prs100.loc['20190101':].cumsum()\
.div(shock_baseline_prs100.loc['20190101':].cumsum())

# %%
# %matplotlib notebook
plt.plot(displacement_all_ref_baseline_sm.loc['20180101':], label='Marginal')
plt.plot(displacement_all_ref_baseline_prs10.loc['20180101':], label='prs10%')
plt.plot(displacement_all_ref_baseline_prs20.loc['20180101':], label='prs20%')
plt.plot(displacement_all_ref_baseline_prs50.loc['20180101':], label='prs50%')
plt.plot(displacement_all_ref_baseline_prs100.loc['20180101':], label='prs100%')

plt.legend()
plt.title('Response ratio of ALL refined production')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Refined usage displacement

# %%
ref_use_response_baseline_sm=sd_baseline_sm.iloc[10:, 6]-sd_baseline_baseline.iloc[10:, 6]
ref_use_response_baseline_prs10=sd_baseline_prs10.iloc[10:, 6]-sd_baseline_baseline.iloc[10:, 6]
ref_use_response_baseline_prs20=sd_baseline_prs20.iloc[10:, 6]-sd_baseline_baseline.iloc[10:, 6]
ref_use_response_baseline_prs50=sd_baseline_prs50.iloc[10:, 6]-sd_baseline_baseline.iloc[10:, 6]
ref_use_response_baseline_prs100=sd_baseline_prs100.iloc[10:, 6]-sd_baseline_baseline.iloc[10:, 6]

# %%
displacement_ref_use_baseline_sm=-ref_use_response_baseline_sm.loc['20190101':].cumsum()\
.div(shock_baseline_sm.loc['20190101':].cumsum())

displacement_ref_use_baseline_prs10=-ref_use_response_baseline_prs10.loc['20190101':].cumsum()\
.div(shock_baseline_prs10.loc['20190101':].cumsum())

displacement_ref_use_baseline_prs20=-ref_use_response_baseline_prs20.loc['20190101':].cumsum()\
.div(shock_baseline_prs20.loc['20190101':].cumsum())

displacement_ref_use_baseline_prs50=-ref_use_response_baseline_prs50.loc['20190101':].cumsum()\
.div(shock_baseline_prs50.loc['20190101':].cumsum())

displacement_ref_use_baseline_prs100=-ref_use_response_baseline_prs100.loc['20190101':].cumsum()\
.div(shock_baseline_prs100.loc['20190101':].cumsum())

# %%
# %matplotlib notebook
plt.plot(displacement_ref_use_baseline_sm.loc['20180101':], label='Marginal')
plt.plot(displacement_ref_use_baseline_prs10.loc['20180101':], label='prs10%')
plt.plot(displacement_ref_use_baseline_prs20.loc['20180101':], label='prs20%')
plt.plot(displacement_ref_use_baseline_prs50.loc['20180101':], label='prs50%')
plt.plot(displacement_ref_use_baseline_prs100.loc['20180101':], label='prs100%')

#plt.legend()
plt.title('Response ratio of Refined usage')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Direct melt displacement

# %%
displacement_dm_use_baseline_sm=-(sd_baseline_sm.iloc[69:, 8]-sd_baseline_baseline.iloc[69:, 8]).cumsum()\
.div(shock_baseline_sm.loc['20190101':].cumsum())
displacement_dm_use_baseline_prs10=-(sd_baseline_prs10.iloc[69:, 8]-sd_baseline_baseline.iloc[69:, 8]).cumsum()\
.div(shock_baseline_prs10.loc['20190101':].cumsum())
displacement_dm_use_baseline_prs20=-(sd_baseline_prs20.iloc[69:, 8]-sd_baseline_baseline.iloc[69:, 8]).cumsum()\
.div(shock_baseline_prs20.loc['20190101':].cumsum())
displacement_dm_use_baseline_prs50=-(sd_baseline_prs50.iloc[69:, 8]-sd_baseline_baseline.iloc[69:, 8]).cumsum()\
.div(shock_baseline_prs50.loc['20190101':].cumsum())
displacement_dm_use_baseline_prs100=-(sd_baseline_prs100.iloc[69:, 8]-sd_baseline_baseline.iloc[69:, 8]).cumsum()\
.div(shock_baseline_prs100.loc['20190101':].cumsum())

# %% [markdown]
# ## All demand displacement

# %%
displacement_all_use_baseline_sm=displacement_dm_use_baseline_sm+displacement_ref_use_baseline_sm
displacement_all_use_baseline_prs10=displacement_dm_use_baseline_prs10+displacement_ref_use_baseline_prs10
displacement_all_use_baseline_prs20=displacement_dm_use_baseline_prs20+displacement_ref_use_baseline_prs20
displacement_all_use_baseline_prs50=displacement_dm_use_baseline_prs50+displacement_ref_use_baseline_prs50
displacement_all_use_baseline_prs100=displacement_dm_use_baseline_prs100+displacement_ref_use_baseline_prs100

# %%
# %matplotlib notebook
plt.plot(displacement_all_use_baseline_sm.loc['20180101':], label='Marginal')
plt.plot(displacement_all_use_baseline_prs10.loc['20180101':], label='prs10%')
plt.plot(displacement_all_use_baseline_prs20.loc['20180101':], label='prs20%')
plt.plot(displacement_all_use_baseline_prs50.loc['20180101':], label='prs50%')
plt.plot(displacement_all_use_baseline_prs100.loc['20180101':], label='prs100%')

#plt.legend()
plt.title('Response ratio of all copper usage')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Supply potentials

# %%
sup_pot_file=pd.read_excel('Te&Se/Supply potential estimate.xlsx', sheet_name='Estimate', index_col=0)
sup_pot_file.index=pd.date_range('19600101', '20180101', freq='AS')

te_cu_ratio=0.105
se_cu_ratio=0.4

# %%
te_se_projection=pd.read_excel('Te&Se/Supply potential estimate.xlsx', sheet_name='Projection', index_col=0)
te_se_projection.index=pd.date_range('20170101', '20400101', freq='AS')

te_high=te_se_projection.loc[:, 'Te high']
te_med=te_se_projection.loc[:, 'Te medium']
te_low=te_se_projection.loc[:, 'Te low']

se_high=te_se_projection.loc[:, 'Se high']
se_med=te_se_projection.loc[:, 'Se medium']
se_low=te_se_projection.loc[:, 'Se low']

# %%
sd_baseline_baseline.loc['19600101':, 'Primary refining production'].index
# Out:
# DatetimeIndex(['1960-01-01', '1961-01-01', '1962-01-01', '1963-01-01',
#                '1964-01-01', '1965-01-01', '1966-01-01', '1967-01-01',
#                '1968-01-01', '1969-01-01', '1970-01-01', '1971-01-01',
#                '1972-01-01', '1973-01-01', '1974-01-01', '1975-01-01',
#                '1976-01-01', '1977-01-01', '1978-01-01', '1979-01-01',
#                '1980-01-01', '1981-01-01', '1982-01-01', '1983-01-01',
#                '1984-01-01', '1985-01-01', '1986-01-01', '1987-01-01',
#                '1988-01-01', '1989-01-01', '1990-01-01', '1991-01-01',
#                '1992-01-01', '1993-01-01', '1994-01-01', '1995-01-01',
#                '1996-01-01', '1997-01-01', '1998-01-01', '1999-01-01',
#                '2000-01-01', '2001-01-01', '2002-01-01', '2003-01-01',
#                '2004-01-01', '2005-01-01', '2006-01-01', '2007-01-01',
#                '2008-01-01', '2009-01-01', '2010-01-01', '2011-01-01',
# ...

# %%
shibe=(sd_baseline_baseline.loc['19600101':, 'Primary refining production'].mul(te_cu_ratio)-\
sd_baseline_prs100.loc['19600101':, 'Primary refining production'].mul(te_cu_ratio))

# %%
# %matplotlib notebook
plt.style.use('ggplot')
#plt.stackplot(sd_baseline_baseline.loc['19600101':, 'Primary refining production'].index, 
#            sd_baseline_baseline.loc['19600101':, 'Primary refining production'].mul(te_cu_ratio), color=(179/256, 206/256, 215/256), 
#              alpha=0.8)

plt.stackplot(sd_baseline_prs100.loc['19600101':, 'Primary refining production'].index, 
              sd_baseline_prs100.loc['19600101':, 'Primary refining production'].mul(te_cu_ratio), shibe,
              colors=[(179/256, 206/256, 215/256), (0.5,0.5,0.5)], 
              alpha=0.8)
plt.plot(sup_pot_file.loc[:, 'Te production (t)'], 'g', label='Historical production')
plt.plot(te_med, 'g', label='Medium growth')
plt.plot([datetime(2018,1,1), datetime(2018,1,1)], [0, 1600], 'k--')
plt.ylabel('Te production and supply posential (t)')
plt.ylim(0,2400)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
(sd_baseline_prs100.loc['19600101':, 'Primary refining production'].mul(te_cu_ratio)-\
sd_baseline_baseline.loc['19600101':, 'Primary refining production'].mul(te_cu_ratio)).cumsum()
# Out:
# 1960-01-01      0.000000
# 1961-01-01      0.000000
# 1962-01-01      0.000000
# 1963-01-01      0.000000
# 1964-01-01      0.000000
# 1965-01-01      0.000000
# 1966-01-01      0.000000
# 1967-01-01      0.000000
# 1968-01-01      0.000000
# 1969-01-01      0.000000
# 1970-01-01      0.000000
# 1971-01-01      0.000000
# 1972-01-01      0.000000
# 1973-01-01      0.000000
# 1974-01-01      0.000000
# 1975-01-01      0.000000
# 1976-01-01      0.000000
# 1977-01-01      0.000000
# 1978-01-01      0.000000
# 1979-01-01      0.000000
# 1980-01-01      0.000000
# 1981-01-01      0.000000
# 1982-01-01      0.000000
# 1983-01-01      0.000000
# 1984-01-01      0.000000
# 1985-01-01      0.000000
# 1986-01-01      0.000000
# 1987-01-01      0.000000
# 1988-01-01      0.000000
# 1989-01-01      0.000000
#                  ...
# 2011-01-01      0.000000
# 2012-01-01      0.000000
# 2013-01-01      0.000000
# 2014-01-01      0.000000
# 2015-01-01      0.000000
# 2016-01-01      0.000000
# ...

# %%
(sd_baseline_baseline.loc['20190101':, 'Primary refining production'].mul(te_cu_ratio)).sum()
# Out:
# 44521.47408435195

# %%
895.769188/44521.47408435195
# Out:
# 0.020119935523761956
